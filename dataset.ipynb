# %%
import pandas as pd
url = "dataset/Dados_mapas.csv"
url1 = "dataset/Players_stats.csv"
url2 = "dataset/agents_master_2022.csv"
pd.read_csv(url).tail(20)
# Out:
#         Map  TotalPicks  GroupAPicks  GroupBPicks  PlayoffsPicks  TotalBans  \
# 0    Ascent          13            1            5              7         11
# 1      Bind           6            0            1              5         18
# 2    Breeze           4            2            0              2         20
# 3  Fracture           9            3            2              4         14
# 4     Haven          14            2            4              8         10
# 5    Icebox          19            5            2             12          5
# 6     Split          11            2            1              8         12
# 7       Nan           1            1            1              1          1
#
#    GroupABans  GroupBBans  PlayoffsBans  AtkWins  AtkWin%  DefWins  DefWin%
# 0           4           0             7      130     46.9    147.0     53.1
# 1           5           4             9       63     48.8     66.0     51.2
# ...

# %%
pd.read_csv(url1,sep=";").head(20)
# Out:
#         Player\t               Team\t     Agents\t  Maps\t  K\t  D\t  A\t  \
# 0       ScreaM\t        Team Liquid\t       Jett\t      11  210  172   75
# 1          Yay\t       OpTic Gaming\t    Chamber\t      21  417  317   69
# 2   Sayaplayer\t          The Guard\t       Jett\t       5   95   75   15
# 3       Jinggg\t          Paper Rex\t       Raze\t      10  184  168   51
# 4        Aspas\t               LOUD\t       Jett\t      11  211  168   35
# 5         MaKo\t                DRX\t      Viper\t      13  225  173  107
# 6        Hoody\t         G2 Esports\t       Sage\t       6  105   97   38
# 7     F0rsakeN\t          Paper Rex\t       Jett\t      10  180  156   36
# 8         Xand\t  Ninjas in Pyjamas\t       Jett\t       7  125  108   25
# 9        H1ber\t             Fnatic\t       Raze\t       4   63   73   22
# 10      Jamppi\t        Team Liquid\t     Breach\t      11  204  175   38
# 11     Fearoth\t             Fnatic\t       Sova\t       4   68   61   19
# ...

# %%
pd.read_csv(url2,sep=";").head(20)
# Out:
#        Agents  Overall Pick Rate  Split    Bind  Haven  Ascent  Icebox  \
# 0        Jett              65.00   40.0    0.00  83.33  100.00   79.17
# 1        Sova              49.17    0.0    8.33  22.22  100.00  100.00
# 2       Viper              45.83   40.0   83.33   0.00    0.00  100.00
# 3     Chamber              44.17   15.0   41.67  33.33   25.00   58.33
# 4        Sage              42.50   90.0   33.33   0.00   12.50   95.83
# 5        Omen              38.33   50.0   16.67  77.78   79.17    4.17
# 6       Kay/o              33.33    5.0    0.00  16.67   70.83   37.50
# 7        Skye              32.50   45.0  100.00  77.78   12.50    0.00
# 8      Breach              30.00   35.0   16.67  66.67    0.00    0.00
# 9        Raze              28.33   80.0  100.00   0.00    0.00    0.00
# 10    KillJoy              26.67    5.0    0.00  50.00   75.00   16.67
# 11      Astra              22.50   50.0   33.33  22.22   16.67    0.00
# ...
